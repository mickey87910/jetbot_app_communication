# %%
# import base64,os
# with open("img/"+str(len(os.listdir('img'))-1)+".jpg", "rb") as imageFile:
#         strr = base64.b64encode(imageFile.read())
#         print(strr)
import socket,time
ss = socket.socket()
ss.connect(("192.168.1.34",9999))

# %%
s = socket.socket()
s.connect(("192.168.1.34",7777))
while True:
    strr = s.recv(10240)
    print(strr)
# Out:
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5615cdf3c3ec> in <module>
#       2 s.connect(("192.168.1.34",7777))
#       3 while True:
# ----> 4     strr = s.recv(10240)
#       5     print(strr)
#
# KeyboardInterrupt:
